# %%
# !pip install watermark

# %load_ext watermark

#python, ipython, packages, and machine characteristics
# %watermark -v -m -p wget,pandas,numpy,geopy,vega,vega_dataset,watermark

# date
print(" ")
# %watermark -u -n -t -z
# Out:
# ...
#   Obtaining dependency information for watermark from https://files.pythonhosted.org/packages/67/ee/32fec350c20ff060064d058c37df53dd1fad74dfea9532faf2868b0512b5/watermark-2.4.3-py2.py3-none-any.whl.metadata
# ...
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# wget        : not installed
# pandas      : 2.0.3
# numpy       : 1.24.3
# geopy       : not installed
# vega        : not installed
# vega_dataset: not installed
# watermark   : 2.4.3
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# CPU cores   : 20
# Architecture: 64bit
#
#
# Last updated: Tue Feb 06 2024 09:44:07W. Central Africa Standard Time

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=937efe1af4b59e999988425552e4e6530cdc3146cc30a0ee330db84a7731e0d8
#   Stored in directory: c:\users\zhmida\appdata\local\pip\cache\wheels\40\b3\0f\a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
# Successfully built wget
# ...

# %%
# !pip install geopy
# Out:
# ...
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.3 kB 682.7 kB/s eta 0:00:01
#      -------------------------------------- 40.3/40.3 kB 640.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    ---------------------------------------- 125.4/125.4 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# !pip install vega
# Out:
# ...
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.1 MB 660.6 kB/s eta 0:00:05
#      - -------------------------------------- 0.1/3.1 MB 1.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.3/3.1 MB 2.3 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 2.5 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 2.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 1.8 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 1.8 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 1.5 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 1.5 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.1 MB 1.5 MB/s eta 0:00:02
# ...

# %%
# %load_ext watermark

#python, ipython, packages, and machine characteristics
# %watermark -v -m -p wget,pandas,numpy,math,sklearn,matplotlib,watermark

# date
print(" ")
# %watermark -u -n -t -z
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# wget      : 3.2
# pandas    : 1.5.3
# numpy     : 1.24.3
# math      : unknown
# sklearn   : 1.3.0
# matplotlib: 3.7.2
# watermark : 2.4.3
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# CPU cores   : 20
# Architecture: 64bit
#
#
# Last updated: Tue Feb 06 2024 10:04:05W. Central Africa Standard Time
