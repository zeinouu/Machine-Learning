# %%
# !pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 653.6 kB/s eta 0:01:00
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
#    ---------------------------------------- 0.2/38.6 MB 2.0 MB/s eta 0:00:20
# ...

# %%
import cv2

# %%
imagePath =r'C:\Users\zhmida\Downloads\dog.jpg'
image = cv2.imread(imagePath)

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
image.shape
# Out:
# (194, 259, 3)

# %%
from skimage.color import rgb2gray
import cv2
img = rgb2gray(cv2.imread(r'C:\Users\zhmida\Downloads\dog.jpg'));
plt.imshow(img)

# %% [markdown]
#  the 194 and 259 are the height and width and the 3 is number of channels

# %%
image
# Out:
# array([[[ 74, 136, 166],
#         [ 74, 136, 166],
#         [ 71, 135, 165],
#         ...,
#         [244, 237, 228],
#         [244, 236, 229],
#         [245, 237, 230]],
#
#        [[ 72, 134, 164],
#         [ 71, 133, 163],
#         [ 68, 132, 162],
#         ...,
#         [245, 238, 229],
#         [245, 237, 230],
#         [246, 238, 231]],
#
#        [[ 66, 130, 160],
#         [ 65, 129, 159],
#         [ 65, 129, 159],
#         ...,
#         [246, 239, 230],
#         [246, 238, 231],
#         [247, 239, 232]],
#
#        ...,
#
#        [[ 64, 159, 168],
#         [ 51, 147, 153],
#         [ 59, 155, 161],
#         ...,
#         [ 49, 127, 134],
#         [ 56, 134, 140],
#         [ 63, 141, 148]],
#
#        [[ 54, 151, 161],
#         [ 60, 158, 166],
#         [ 68, 166, 174],
#         ...,
#         [ 66, 143, 152],
#         [ 66, 144, 151],
#         [ 67, 144, 153]],
#
#        [[ 53, 151, 161],
#         [ 59, 157, 167],
#         [ 68, 166, 174],
# ...

# %%
image[0][0]
# Out:
# array([ 74, 136, 166], dtype=uint8)

# %%
size=(32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[ 60, 127, 156],
#         [ 59, 142, 168],
#         [ 45, 123, 139],
#         ...,
#         [105, 132, 137],
#         [218, 213, 208],
#         [234, 229, 219]],
#
#        [[ 52, 130, 153],
#         [ 60, 143, 165],
#         [ 45, 119, 136],
#         ...,
#         [ 65,  99,  99],
#         [ 94, 108, 104],
#         [148, 163, 159]],
#
#        [[ 48, 135, 152],
#         [ 54, 137, 154],
#         [ 38, 107, 124],
#         ...,
#         [ 83, 101, 102],
#         [144, 152, 150],
#         [ 58,  95,  95]],
#
#        ...,
#
#        [[ 57, 157, 163],
#         [ 57, 157, 162],
#         [ 35, 135, 141],
#         ...,
#         [ 62, 159, 159],
#         [ 55, 160, 161],
#         [ 40, 133, 137]],
#
#        [[ 50, 138, 145],
#         [ 78, 166, 173],
#         [ 63, 146, 154],
#         ...,
#         [ 42, 141, 141],
#         [ 40, 135, 138],
#         [ 67, 152, 157]],
#
#        [[ 72, 167, 173],
#         [ 64, 158, 164],
#         [ 58, 147, 154],
# ...

# %%
len(resized_image_feature_vector)
# Out:
# 32

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)

# %%
image_grayscale
# Out:
# array([[138, 138, 137, ..., 235, 235, 236],
#        [136, 135, 134, ..., 236, 236, 237],
#        [132, 131, 131, ..., 237, 237, 238],
#        ...,
#        [151, 138, 146, ..., 120, 127, 134],
#        [143, 149, 157, ..., 137, 137, 138],
#        [143, 149, 157, ..., 137, 137, 138]], dtype=uint8)

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (194, 259)

# %% [markdown]
# the last dimension is one because this is a single channel image

# %%
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)# we use expand_dims to expand the third axis
expanded_image_grayscale.shape
# Out:
# (194, 259, 1)

# %% [markdown]
# In our case this will add additional dimension to represent the pixel intensity.

# %%
expanded_image_grayscale
# Out:
# array([[[138],
#         [138],
#         [137],
#         ...,
#         [235],
#         [235],
#         [236]],
#
#        [[136],
#         [135],
#         [134],
#         ...,
#         [236],
#         [236],
#         [237]],
#
#        [[132],
#         [131],
#         [131],
#         ...,
#         [237],
#         [237],
#         [238]],
#
#        ...,
#
#        [[151],
#         [138],
#         [146],
#         ...,
#         [120],
#         [127],
#         [134]],
#
#        [[143],
#         [149],
#         [157],
#         ...,
#         [137],
#         [137],
#         [138]],
#
#        [[143],
#         [149],
#         [157],
#         ...,
#         [137],
#         [137],
#         [138]]], dtype=uint8)
